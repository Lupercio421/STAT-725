# %% [markdown]
# **[Beginner][Tutorial] Intel Image Classification**
#
# Hello, Kagglers!
#
# In this kernel, i will show you how to build the basic model in Tensorflow Keras. First of all i will use Convolutional Neural Network (CNN) in this kernel to predict upto 6 class labels.
#
# First, import the important libraries.

# %%
import tensorflow.keras.layers as Layers
import tensorflow.keras.activations as Actications
import tensorflow.keras.models as Models
import tensorflow.keras.optimizers as Optimizer
import tensorflow.keras.metrics as Metrics
import tensorflow.keras.utils as Utils
from keras.utils.vis_utils import model_to_dot
import os
import matplotlib.pyplot as plot
import cv2
import numpy as np
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix as CM
from sklearn.model_selection import train_test_split
from random import randint
from IPython.display import SVG
import matplotlib.gridspec as gridspec

# %% [markdown]
# Now, We need to prepare our data to feed into the model. There is a builtin method in [Keras](https://keras.io/preprocessing/image/) that can extract your images from folders. But, I recommend you to make your own function for this purpose so you can practice the python.
#
# Following is the gernalized function used to extract data from the directory.

# %%
def get_images(directory):
    Images = []
    Labels = []  # 0 for Building , 1 for forest, 2 for glacier, 3 for mountain, 4 for Sea , 5 for Street
    label = 0
    
    for labels in os.listdir(directory): #Main Directory where each class label is present as folder name.
        if labels == 'glacier': #Folder contain Glacier Images get the '2' class label.
            label = 2
        elif labels == 'sea':
            label = 4
        elif labels == 'buildings':
            label = 0
        elif labels == 'forest':
            label = 1
        elif labels == 'street':
            label = 5
        elif labels == 'mountain':
            label = 3
        
        for image_file in os.listdir(directory+labels): #Extracting the file name of the image from Class Label folder
            image = cv2.imread(directory+labels+r'/'+image_file) #Reading the image (OpenCV)
            image = cv2.resize(image,(150,150)) #Resize the image, Some images are different sizes. (Resizing is very Important)
            Images.append(image)
            Labels.append(label)
    
    return shuffle(Images,Labels,random_state=817328462) #Shuffle the dataset you just prepared.

def get_classlabel(class_code):
    labels = {2:'glacier', 4:'sea', 0:'buildings', 1:'forest', 5:'street', 3:'mountain'}
    
    return labels[class_code]

# %%
train_Images, train_Labels = get_images('C:/Users/Daniel/Downloads/Intel_images/seg_train/seg_train/') #Extract the training images from the folders.

train_Images = np.array(train_Images) #converting the list of images to numpy array.
train_Labels = np.array(train_Labels)

# %% [markdown]
# Lets find shape of our traing data.
#
# As you see, The Training data is in shape of (Number of Training Images, Width of image, Height of image, Channel of image). This shape is very important. If you didnot resize the images to same size. It should be (No. of images,) shape. So, using this shape you cant feed the images to the model.

# %%
print("Shape of training Images:",train_Images.shape)
print("Shape of training Labels:",train_Images.shape)
# Out:
# Shape of training Images: (14034, 150, 150, 3)
# Shape of training Labels: (14034, 150, 150, 3)

# %% [markdown]
# Let us look some random images of our dataset.

# %%
f,ax = plot.subplots(5,5) 
f.subplots_adjust(0,0,3,3)
for i in range(0,5,1):
    for j in range(0,5,1):
        rnd_number = randint(0,len(Images))
        ax[i,j].imshow(Images[rnd_number])
        ax[i,j].set_title(get_classlabel(Labels[rnd_number]))
        ax[i,j].axis('off')

# %% [markdown]
# Now, Create the CNN model to predict the class labels.This is the basic CNN model.

# %%
model = Models.Sequential()

model.add(Layers.Conv2D(200,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Conv2D(180,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(140,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(100,kernel_size=(3,3),activation='relu'))
model.add(Layers.Conv2D(50,kernel_size=(3,3),activation='relu'))
model.add(Layers.MaxPool2D(5,5))
model.add(Layers.Flatten())
model.add(Layers.Dense(180,activation='relu'))
model.add(Layers.Dense(100,activation='relu'))
model.add(Layers.Dense(50,activation='relu'))
model.add(Layers.Dropout(rate=0.5))
model.add(Layers.Dense(6,activation='softmax'))

model.compile(optimizer=Optimizer.Adam(lr=0.0001),loss='sparse_categorical_crossentropy',metrics=['accuracy'])

model.summary()
SVG(model_to_dot(model).create(prog='dot', format='svg'))
Utils.plot_model(model,to_file='model.png',show_shapes=True)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 148, 148, 200)     5600
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 146, 146, 180)     324180
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 29, 29, 180)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 27, 27, 180)       291780
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 25, 25, 140)       226940
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 23, 23, 100)       126100
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 21, 21, 50)        45050
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 4, 4, 50)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 800)               0
# _________________________________________________________________
# dense (Dense)                (None, 180)               144180
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               18100
# _________________________________________________________________
# dense_2 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout (Dropout)            (None, 50)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 6)                 306
# =================================================================
# Total params: 1,187,286
# Trainable params: 1,187,286
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Now, lets train the model with validation split equal to 30% from training data. Validation split is used to determine that our model is not geting over-fitted.

# %%
trained = model.fit(Images,Labels,epochs=35,validation_split=0.30)
# Out:
# Train on 9823 samples, validate on 4211 samples
# Epoch 1/35
# 9823/9823 [==============================] - 52s 5ms/sample - loss: 1.5607 - acc: 0.3866 - val_loss: 1.1576 - val_acc: 0.5450
# Epoch 2/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 1.1695 - acc: 0.5572 - val_loss: 1.0458 - val_acc: 0.6407
# Epoch 3/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 1.0056 - acc: 0.6320 - val_loss: 0.9211 - val_acc: 0.6711
# Epoch 4/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.8977 - acc: 0.6759 - val_loss: 0.7073 - val_acc: 0.7497
# Epoch 5/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.7989 - acc: 0.7252 - val_loss: 0.8003 - val_acc: 0.7157
# Epoch 6/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.7220 - acc: 0.7473 - val_loss: 0.5902 - val_acc: 0.7929
# Epoch 7/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.6742 - acc: 0.7681 - val_loss: 0.5873 - val_acc: 0.7960
# Epoch 8/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.6133 - acc: 0.7939 - val_loss: 0.6164 - val_acc: 0.7905
# Epoch 9/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.5832 - acc: 0.8079 - val_loss: 0.5443 - val_acc: 0.8129
# Epoch 10/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.5342 - acc: 0.8202 - val_loss: 0.5025 - val_acc: 0.8283
# Epoch 11/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.5092 - acc: 0.8311 - val_loss: 0.5506 - val_acc: 0.8119
# Epoch 12/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.4803 - acc: 0.8447 - val_loss: 0.4888 - val_acc: 0.8300
# Epoch 13/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.4487 - acc: 0.8495 - val_loss: 0.4805 - val_acc: 0.8338
# Epoch 14/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.4125 - acc: 0.8626 - val_loss: 0.5747 - val_acc: 0.8214
# Epoch 15/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.3651 - acc: 0.8788 - val_loss: 0.5187 - val_acc: 0.8312
# Epoch 16/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.3591 - acc: 0.8793 - val_loss: 0.5028 - val_acc: 0.8397
# Epoch 17/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.3236 - acc: 0.8924 - val_loss: 0.5019 - val_acc: 0.8426
# Epoch 18/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2981 - acc: 0.9017 - val_loss: 0.5542 - val_acc: 0.8321
# Epoch 19/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2776 - acc: 0.9090 - val_loss: 0.5692 - val_acc: 0.8385
# Epoch 20/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2644 - acc: 0.9146 - val_loss: 0.6219 - val_acc: 0.8133
# Epoch 21/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2298 - acc: 0.9251 - val_loss: 0.7196 - val_acc: 0.8202
# Epoch 22/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2137 - acc: 0.9300 - val_loss: 0.6427 - val_acc: 0.8295
# Epoch 23/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.2135 - acc: 0.9311 - val_loss: 0.6242 - val_acc: 0.8416
# Epoch 24/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1772 - acc: 0.9422 - val_loss: 0.6359 - val_acc: 0.8402
# Epoch 25/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1887 - acc: 0.9412 - val_loss: 0.7937 - val_acc: 0.7920
# Epoch 26/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1544 - acc: 0.9478 - val_loss: 0.7407 - val_acc: 0.8319
# Epoch 27/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1547 - acc: 0.9471 - val_loss: 0.7326 - val_acc: 0.8378
# Epoch 28/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1529 - acc: 0.9528 - val_loss: 0.6751 - val_acc: 0.8380
# Epoch 29/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1237 - acc: 0.9603 - val_loss: 0.7414 - val_acc: 0.8426
# Epoch 30/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1241 - acc: 0.9589 - val_loss: 0.8716 - val_acc: 0.8183
# Epoch 31/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1118 - acc: 0.9649 - val_loss: 0.8594 - val_acc: 0.8407
# Epoch 32/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.0946 - acc: 0.9696 - val_loss: 0.8600 - val_acc: 0.8198
# Epoch 33/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.0884 - acc: 0.9723 - val_loss: 0.8127 - val_acc: 0.8366
# Epoch 34/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.0944 - acc: 0.9699 - val_loss: 1.0923 - val_acc: 0.8155
# Epoch 35/35
# 9823/9823 [==============================] - 47s 5ms/sample - loss: 0.1085 - acc: 0.9673 - val_loss: 0.9003 - val_acc: 0.8247

# %%
plot.plot(trained.history['acc'])
plot.plot(trained.history['val_acc'])
plot.title('Model accuracy')
plot.ylabel('Accuracy')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

plot.plot(trained.history['loss'])
plot.plot(trained.history['val_loss'])
plot.title('Model loss')
plot.ylabel('Loss')
plot.xlabel('Epoch')
plot.legend(['Train', 'Test'], loc='upper left')
plot.show()

# %% [markdown]
# To evaluate a model, there are many methods are proposed to evaluate the model. I use Accuracy to evaluate the performance of my model.

# %%
test_images,test_labels = get_images('../input/seg_test/seg_test/')
test_images = np.array(test_images)
test_labels = np.array(test_labels)
model.evaluate(test_images,test_labels, verbose=1)
# Out:
# 3000/3000 [==============================] - 4s 1ms/sample - loss: 0.7984 - acc: 0.8307
# [0.7983592193126678, 0.83066666]

# %% [markdown]
# Lets predict the images from the "pred" folder.

# %%
pred_images,no_labels = get_images('../input/seg_pred/')
pred_images = np.array(pred_images)
pred_images.shape
# Out:
# (7301, 150, 150, 3)

# %% [markdown]
# Following image shows the predicted class label on top of the image and probabilities below of the image.

# %%
fig = plot.figure(figsize=(30, 30))
outer = gridspec.GridSpec(5, 5, wspace=0.2, hspace=0.2)

for i in range(25):
    inner = gridspec.GridSpecFromSubplotSpec(2, 1,subplot_spec=outer[i], wspace=0.1, hspace=0.1)
    rnd_number = randint(0,len(pred_images))
    pred_image = np.array([pred_images[rnd_number]])
    pred_class = get_classlabel(model.predict_classes(pred_image)[0])
    pred_prob = model.predict(pred_image).reshape(6)
    for j in range(2):
        if (j%2) == 0:
            ax = plot.Subplot(fig, inner[j])
            ax.imshow(pred_image[0])
            ax.set_title(pred_class)
            ax.set_xticks([])
            ax.set_yticks([])
            fig.add_subplot(ax)
        else:
            ax = plot.Subplot(fig, inner[j])
            ax.bar([0,1,2,3,4,5],pred_prob)
            fig.add_subplot(ax)


fig.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/matplotlib/figure.py:448: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %% [markdown]
# I hope you like my kernel. Feel free to ask any question in the comment section. I am looking forward for your **sugestions**!
